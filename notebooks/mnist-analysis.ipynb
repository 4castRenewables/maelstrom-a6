# %% [markdown]
# ### Analysis of the DCv2 Results for the MNIST Dataset
#
# This notebook analyses the results of the unsupervised clustering with DCv2 on the MNIST dataset provided by `torchvision`.
#
# The aspects analyzed are:
#
# 1. Accuracy per MLP head.
# 2. Similarity between the clustering results of the different heads that cluster the same crops (which should become similar).
#
# ### Results
#
# 1. After 800 epochs, the accuracy varies between $0.35-0.45\%$ for the 4 heads.
# 2. The heads that cluster the same crops have almost no matching in terms of cluster assignments.
# 3. When calculating the class count per cluster, and the samples closest to the cluster centers, it appears that
#    there are two clusters for the number 1 and 6, and at least one cluster contains a lot of 0, while still being quite inhomogeneous.
#    Other clusters are always very inhomogeneous.
#
#       <details><summary>Logs</summary>
#
#       ```
#       Counts per dataset label for cluster 0: tensor([ 439, 1852,  286,  576,  398, 1351,   82,  317,  327,  421],
#        device='cuda:0')
#       Counts per dataset label for cluster 1: tensor([   5,    8,  788, 1665, 1673,  277,    0,  218,  152, 2000],
#              device='cuda:0')
#       Counts per dataset label for cluster 2: tensor([   6,   52, 1144,  517,  231,  265,   41,  130, 1118,  319],
#              device='cuda:0')
#       Counts per dataset label for cluster 3: tensor([ 624,    1,   36,  460,  254,  550,    1, 3570,   96,  233],
#              device='cuda:0')
#       Counts per dataset label for cluster 4: tensor([   8,   34,  639,  602, 1516, 1303,   42,  102,  830, 1095],
#              device='cuda:0')
#       Counts per dataset label for cluster 5: tensor([  2,  34, 814, 540, 313, 335,   9, 141, 795, 399], device='cuda:0')
#       Counts per dataset label for cluster 6: tensor([   4,   10,   19,    0,   27,  196, 4865,    0,  577,    2],
#              device='cuda:0')
#       Counts per dataset label for cluster 7: tensor([4833,   31, 1257,  774,  445,  684,  868, 1586, 1339,  424],
#              device='cuda:0')
#       Counts per dataset label for cluster 8: tensor([   1,   29,  969,  996,  985,  460,    6,  191,  612, 1053],
#              device='cuda:0')
#       Counts per dataset label for cluster 9: tensor([   1, 4691,    6,    1,    0,    0,    4,   10,    5,    3],
#              device='cuda:0')
#       accuracy=0.43896666169166565
#       Counts per dataset label for cluster 0: tensor([   8,   35,  637,  585, 1498, 1296,   42,  101,  830, 1066],
#              device='cuda:0')
#       Counts per dataset label for cluster 1: tensor([   3,    6,  582, 1100, 1254,  235,    0,  136,  123, 1427],
#              device='cuda:0')
#       Counts per dataset label for cluster 2: tensor([ 157,   37, 1343,  430,  112,  169,  883,   98, 1300,  211],
#              device='cuda:0')
#       Counts per dataset label for cluster 3: tensor([   7,   60, 1383,  686,  362,  370,   46,  161, 1355,  439],
#              device='cuda:0')
#       Counts per dataset label for cluster 4: tensor([2126,    1,   18,  276,  101,  422,    1, 1883,   83,   93],
#              device='cuda:0')
#       Counts per dataset label for cluster 5: tensor([ 919, 1806,  317,  995,  631, 1860,   84, 3427,  410,  632],
#              device='cuda:0')
#       Counts per dataset label for cluster 6: tensor([   3,    5,  691, 1228, 1146,  179,    1,  177,  178, 1363],
#              device='cuda:0')
#       Counts per dataset label for cluster 7: tensor([  1,  47, 950, 692, 440, 543,   8, 191, 933, 552], device='cuda:0')
#       Counts per dataset label for cluster 8: tensor([2695,    0,   12,  138,  271,  153,    6,   82,   66,  161],
#              device='cuda:0')
#       Counts per dataset label for cluster 9: tensor([   4, 4745,   25,    1,   27,  194, 4847,    9,  573,    5],
#              device='cuda:0')
#       accuracy=0.3509833514690399
#       Counts per dataset label for cluster 0: tensor([   3,    8, 1000, 1843, 1638,  285,    1,  251,  311, 1973],
#              device='cuda:0')
#       Counts per dataset label for cluster 1: tensor([   7,   99, 1952, 1094,  606,  798,   48,  283, 1963,  759],
#              device='cuda:0')
#       Counts per dataset label for cluster 2: tensor([ 568,    0,   35,  441,  244,  532,    1, 3350,   93,  226],
#              device='cuda:0')
#       Counts per dataset label for cluster 3: tensor([   1, 4736,    6,    1,    0,    0,    3,    9,    5,    3],
#              device='cuda:0')
#       Counts per dataset label for cluster 4: tensor([   4,   10,   19,    0,   27,  198, 4850,    0,  584,    2],
#              device='cuda:0')
#       Counts per dataset label for cluster 5: tensor([ 157,   43, 1533,  510,  145,  205,  882,  126, 1499,  263],
#              device='cuda:0')
#       Counts per dataset label for cluster 6: tensor([2053,    1,   17,  261,  104,  400,    1, 1652,   76,   92],
#              device='cuda:0')
#       Counts per dataset label for cluster 7: tensor([2683,    0,   12,  136,  266,  152,    9,   78,   66,  162],
#              device='cuda:0')
#       Counts per dataset label for cluster 8: tensor([   3,   11,  676,  940, 1307,  293,    0,  138,  188, 1376],
#              device='cuda:0')
#       Counts per dataset label for cluster 9: tensor([ 444, 1834,  708,  905, 1505, 2558,  123,  378, 1066, 1093],
#              device='cuda:0')
#       accuracy=0.45125001668930054
#       Counts per dataset label for cluster 0: tensor([ 163,   49, 1639,  560,  167,  224,  884,  136, 1603,  307],
#              device='cuda:0')
#       Counts per dataset label for cluster 1: tensor([   1, 4467,    5,    0,    0,    0,    3,    9,    3,    3],
#              device='cuda:0')
#       Counts per dataset label for cluster 2: tensor([ 438, 1608,  283,  580,  399, 1353,   83,  315,  326,  421],
#              device='cuda:0')
#       Counts per dataset label for cluster 3: tensor([   3,   68, 1890, 1554, 1295,  824,   20,  346, 1505, 1427],
#              device='cuda:0')
#       Counts per dataset label for cluster 4: tensor([ 610,    0,   37,  450,  249,  554,    1, 3521,   94,  233],
#              device='cuda:0')
#       Counts per dataset label for cluster 5: tensor([   4,   11,   19,    0,   27,  194, 4855,    0,  594,    2],
#              device='cuda:0')
#       Counts per dataset label for cluster 6: tensor([   9,   35,  640,  591, 1508, 1299,   42,  103,  828, 1095],
#              device='cuda:0')
#       Counts per dataset label for cluster 7: tensor([  0, 468,   1,   1,   0,   0,   0,   0,   2], device='cuda:0')
#       Counts per dataset label for cluster 8: tensor([4690,   28,  633,  686,  493,  694,   30, 1614,  734,  400],
#              device='cuda:0')
#       Counts per dataset label for cluster 9: tensor([   5,    8,  811, 1709, 1704,  279,    0,  221,  162, 2061],
#              device='cuda:0')
#       accuracy=0.44511666893959045Counts per dataset label for cluster 0: tensor([ 439, 1852,  286,  576,  398, 1351,   82,  317,  327,  421],
#              device='cuda:0')
#       Counts per dataset label for cluster 1: tensor([   5,    8,  788, 1665, 1673,  277,    0,  218,  152, 2000],
#              device='cuda:0')
#       Counts per dataset label for cluster 2: tensor([   6,   52, 1144,  517,  231,  265,   41,  130, 1118,  319],
#              device='cuda:0')
#       Counts per dataset label for cluster 3: tensor([ 624,    1,   36,  460,  254,  550,    1, 3570,   96,  233],
#              device='cuda:0')
#       Counts per dataset label for cluster 4: tensor([   8,   34,  639,  602, 1516, 1303,   42,  102,  830, 1095],
#              device='cuda:0')
#       Counts per dataset label for cluster 5: tensor([  2,  34, 814, 540, 313, 335,   9, 141, 795, 399], device='cuda:0')
#       Counts per dataset label for cluster 6: tensor([   4,   10,   19,    0,   27,  196, 4865,    0,  577,    2],
#              device='cuda:0')
#       Counts per dataset label for cluster 7: tensor([4833,   31, 1257,  774,  445,  684,  868, 1586, 1339,  424],
#              device='cuda:0')
#       Counts per dataset label for cluster 8: tensor([   1,   29,  969,  996,  985,  460,    6,  191,  612, 1053],
#              device='cuda:0')
#       Counts per dataset label for cluster 9: tensor([   1, 4691,    6,    1,    0,    0,    4,   10,    5,    3],
#              device='cuda:0')
#       accuracy=0.43896666169166565
#       Counts per dataset label for cluster 0: tensor([   8,   35,  637,  585, 1498, 1296,   42,  101,  830, 1066],
#              device='cuda:0')
#       Counts per dataset label for cluster 1: tensor([   3,    6,  582, 1100, 1254,  235,    0,  136,  123, 1427],
#              device='cuda:0')
#       Counts per dataset label for cluster 2: tensor([ 157,   37, 1343,  430,  112,  169,  883,   98, 1300,  211],
#              device='cuda:0')
#       Counts per dataset label for cluster 3: tensor([   7,   60, 1383,  686,  362,  370,   46,  161, 1355,  439],
#              device='cuda:0')
#       Counts per dataset label for cluster 4: tensor([2126,    1,   18,  276,  101,  422,    1, 1883,   83,   93],
#              device='cuda:0')
#       Counts per dataset label for cluster 5: tensor([ 919, 1806,  317,  995,  631, 1860,   84, 3427,  410,  632],
#              device='cuda:0')
#       Counts per dataset label for cluster 6: tensor([   3,    5,  691, 1228, 1146,  179,    1,  177,  178, 1363],
#              device='cuda:0')
#       Counts per dataset label for cluster 7: tensor([  1,  47, 950, 692, 440, 543,   8, 191, 933, 552], device='cuda:0')
#       Counts per dataset label for cluster 8: tensor([2695,    0,   12,  138,  271,  153,    6,   82,   66,  161],
#              device='cuda:0')
#       Counts per dataset label for cluster 9: tensor([   4, 4745,   25,    1,   27,  194, 4847,    9,  573,    5],
#              device='cuda:0')
#       accuracy=0.3509833514690399
#       Counts per dataset label for cluster 0: tensor([   3,    8, 1000, 1843, 1638,  285,    1,  251,  311, 1973],
#              device='cuda:0')
#       Counts per dataset label for cluster 1: tensor([   7,   99, 1952, 1094,  606,  798,   48,  283, 1963,  759],
#              device='cuda:0')
#       Counts per dataset label for cluster 2: tensor([ 568,    0,   35,  441,  244,  532,    1, 3350,   93,  226],
#              device='cuda:0')
#       Counts per dataset label for cluster 3: tensor([   1, 4736,    6,    1,    0,    0,    3,    9,    5,    3],
#              device='cuda:0')
#       Counts per dataset label for cluster 4: tensor([   4,   10,   19,    0,   27,  198, 4850,    0,  584,    2],
#              device='cuda:0')
#       Counts per dataset label for cluster 5: tensor([ 157,   43, 1533,  510,  145,  205,  882,  126, 1499,  263],
#              device='cuda:0')
#       Counts per dataset label for cluster 6: tensor([2053,    1,   17,  261,  104,  400,    1, 1652,   76,   92],
#              device='cuda:0')
#       Counts per dataset label for cluster 7: tensor([2683,    0,   12,  136,  266,  152,    9,   78,   66,  162],
#              device='cuda:0')
#       Counts per dataset label for cluster 8: tensor([   3,   11,  676,  940, 1307,  293,    0,  138,  188, 1376],
#              device='cuda:0')
#       Counts per dataset label for cluster 9: tensor([ 444, 1834,  708,  905, 1505, 2558,  123,  378, 1066, 1093],
#              device='cuda:0')
#       accuracy=0.45125001668930054
#       Counts per dataset label for cluster 0: tensor([ 163,   49, 1639,  560,  167,  224,  884,  136, 1603,  307],
#              device='cuda:0')
#       Counts per dataset label for cluster 1: tensor([   1, 4467,    5,    0,    0,    0,    3,    9,    3,    3],
#              device='cuda:0')
#       Counts per dataset label for cluster 2: tensor([ 438, 1608,  283,  580,  399, 1353,   83,  315,  326,  421],
#              device='cuda:0')
#       Counts per dataset label for cluster 3: tensor([   3,   68, 1890, 1554, 1295,  824,   20,  346, 1505, 1427],
#              device='cuda:0')
#       Counts per dataset label for cluster 4: tensor([ 610,    0,   37,  450,  249,  554,    1, 3521,   94,  233],
#              device='cuda:0')
#       Counts per dataset label for cluster 5: tensor([   4,   11,   19,    0,   27,  194, 4855,    0,  594,    2],
#              device='cuda:0')
#       Counts per dataset label for cluster 6: tensor([   9,   35,  640,  591, 1508, 1299,   42,  103,  828, 1095],
#              device='cuda:0')
#       Counts per dataset label for cluster 7: tensor([  0, 468,   1,   1,   0,   0,   0,   0,   2], device='cuda:0')
#       Counts per dataset label for cluster 8: tensor([4690,   28,  633,  686,  493,  694,   30, 1614,  734,  400],
#              device='cuda:0')
#       Counts per dataset label for cluster 9: tensor([   5,    8,  811, 1709, 1704,  279,    0,  221,  162, 2061],
#              device='cuda:0')
#       accuracy=0.44511666893959045
#       ```
# </details>
#
# This concludes that the clustering of the MNIST dataset with DCv2 doesn't seem to work well. Or at least only somewhat well for the numbers 0, 1 and 6.

# %%
import sklearn.metrics
import torch
import pathlib
import torchvision

device = torch.device("cuda:0")

# %%
mnist = torchvision.datasets.MNIST(
    root="/p/scratch/deepacf/maelstrom/emmerich1/data/mnist/",
    train=True,
    download=True,
)
# Out:
# ...
# 100%|██████████| 9912422/9912422 [00:00<00:00, 283723530.36it/s]
# Extracting /p/scratch/deepacf/maelstrom/emmerich1/data/mnist/MNIST/raw/train-images-idx3-ubyte.gz to /p/scratch/deepacf/maelstrom/emmerich1/data/mnist/MNIST/raw
#
# ...
# 100%|██████████| 28881/28881 [00:00<00:00, 121135693.82it/s]
# Extracting /p/scratch/deepacf/maelstrom/emmerich1/data/mnist/MNIST/raw/train-labels-idx1-ubyte.gz to /p/scratch/deepacf/maelstrom/emmerich1/data/mnist/MNIST/raw
#
# ...
# 100%|██████████| 1648877/1648877 [00:00<00:00, 84496767.14it/s]
# Extracting /p/scratch/deepacf/maelstrom/emmerich1/data/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to /p/scratch/deepacf/maelstrom/emmerich1/data/mnist/MNIST/raw
# ...
# 100%|██████████| 4542/4542 [00:00<00:00, 24549650.47it/s]
# Extracting /p/scratch/deepacf/maelstrom/emmerich1/data/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to /p/scratch/deepacf/maelstrom/emmerich1/data/mnist/MNIST/raw

# %%
import numpy as np
import sklearn.cluster
import sklearn.mixture


def infer_dataset_labels_for_clusters(
    labels_true: torch.LongTensor, labels_pred: torch.LongTensor
) -> dict[int, int]:
    """Infer which dataset label corresponds to the respective clusters.

    Parameters
    ----------
    cluster_indexes: torch.Tensor
        The cluster indexes.
    labels_true : np.ndarray
        The true labels for each sample from the dataset.

    Returns
    -------
    dict[int, int]
        Contains the k-Means cluster labels as keys, and the
        respective real dataset label as value.

    """
    # Maps cluster labels -> dataset labels (e.g. numbers for MNIST)
    # E.g. cluster index 2 might correspond
    # to the dataset label 7 (number 7 for MNIST).
    # Then, `labels_map = {..., 2: 7, ...}`.
    labels_map: dict[int, int] = {}
    n_clusters = labels_pred.unique().max() + 1

    for i in range(n_clusters):
        # Get indexes of the samples assigned to the cluster.

        # Get the dataset labels for each of the samples.
        labels = labels_true[labels_pred == i]
        # print(f"Dataset labels of the samples assigned to cluster {i}: {labels}")

        # Get the number of samples for each dataset label.
        counts = labels.bincount()
        print(f"Counts per dataset label for cluster {i}: {counts}")

        # Assign dataset label with most samples to the respective cluster.
        labels_map[i] = counts.argmax()
        # print(f"Cluster {i} corresponds to dataset label {labels_map[i]}")

    return labels_map


def infer_predicted_dataset_labels(
    labels_pred: torch.LongTensor, cluster_labels_map: dict[int, int]
) -> np.ndarray:
    """Infers the respective dataset label predicted by k-Means for each sample."""
    return torch.LongTensor(
        [cluster_labels_map[int(i)] for i in labels_pred]
    ).to(device=device)


def accuracy_score(
    labels_true: torch.LongTensor, labels_pred: torch.LongTensor
) -> float:
    return float((labels_true == labels_pred).sum() / labels_true.shape[0])

# %%
load_to_first_gpu = lambda storage, loc: storage.cuda(0)
path = pathlib.Path("/p/scratch/deepacf/maelstrom/emmerich1/dcv2/mnist-1-node-1-gpu/results/tensors/")
indexes = torch.load(
    path / "epoch-799-indexes.pt",
    map_location=load_to_first_gpu,
)
assignments = torch.load(
    path / "epoch-799-assignments.pt",
    map_location=load_to_first_gpu,
)

# %%
for i in range(assignments.shape[0]):
    labels_dcv2 = assignments[i]
    # print(f"{labels_dcv2=}")

    labels_mnist = torch.LongTensor([sample[1] for sample in mnist]).to(
        device=device
    )
    # print(f"{labels_mnist=}")

    labels_map = infer_dataset_labels_for_clusters(
        labels_true=labels_mnist, labels_pred=labels_dcv2
    )
    # print(f"{labels_map=}")

    labels_dcv2_mnist = infer_predicted_dataset_labels(
        labels_pred=labels_dcv2, cluster_labels_map=labels_map
    )
    # print(f"{labels_dcv2_mnist=}")

    accuracy = accuracy_score(
        labels_true=labels_mnist, labels_pred=labels_dcv2_mnist
    )
    print(f"{accuracy=}")
# Out:
# Counts per dataset label for cluster 0: tensor([   1, 5131,   18,    2,    2,    0,    1, 4925,    3,   17],
#        device='cuda:0')
# Counts per dataset label for cluster 1: tensor([  15,    0,    1,    0,   20,    8, 5556,    0,    4,    1],
#        device='cuda:0')
# Counts per dataset label for cluster 2: tensor([5878,    0,    1,    0,    0,    3,    3,   18,    4,    1],
#        device='cuda:0')
# Counts per dataset label for cluster 3: tensor([   6, 1431,    2,  329, 3094,  430,    4,  564,  440, 2977],
#        device='cuda:0')
# Counts per dataset label for cluster 4: tensor([   0,   77, 3111,    7,    0,    0,    0,    5,    5,    1],
#        device='cuda:0')
# Counts per dataset label for cluster 5: tensor([   0,    8,    3, 1511, 1350,    3,    0,  393,    6, 1199],
#        device='cuda:0')
# Counts per dataset label for cluster 6: tensor([  18,    6,    6,    3,    1, 3328,  345,    2, 3862,    7],
#        device='cuda:0')
# ...

# %%
for head_1, head_2 in [
    (assignments[0], assignments[2]),
    (assignments[1], assignments[3]),
]:
    labels_true = head_1
    labels_pred = head_2
    labels_map = infer_dataset_labels_for_clusters(
        labels_true=labels_true, labels_pred=labels_pred
    )
    # print(f"{labels_map=}")

    labels_dcv2_mnist = infer_predicted_dataset_labels(
        labels_pred=labels_pred, cluster_labels_map=labels_map
    )
    # print(f"{labels_dcv2_mnist=}")

    accuracy = accuracy_score(labels_true=labels_true, labels_pred=labels_pred)
    print(f"{accuracy=}")
# Out:
# Counts per dataset label for cluster 0: tensor([   0,    0,    0,    0, 3014,   15,    0, 7042], device='cuda:0')
# Counts per dataset label for cluster 1: tensor([4973,    0,    9,   55,   25,    1,    0,    0,    0,    2],
#        device='cuda:0')
# Counts per dataset label for cluster 2: tensor([   0, 5604], device='cuda:0')
# Counts per dataset label for cluster 3: tensor([5127,    0,    0,   27,   11,    1], device='cuda:0')
# Counts per dataset label for cluster 4: tensor([   0,    0,    0,    2,  146, 3573,    0,    0, 2889], device='cuda:0')
# Counts per dataset label for cluster 5: tensor([   0,    0,    0,    0,    0,  863,    0,    2,    0, 3308],
#        device='cuda:0')
# Counts per dataset label for cluster 6: tensor([   0,    0,    0, 9193,    7,   19,    0,   11,    2,   76],
#        device='cuda:0')
# Counts per dataset label for cluster 7: tensor([   0,    0, 5898,    0,    1,    0,    0,    0,    1], device='cuda:0')
# ...

# %%
distances = torch.load(
    path / "epoch-799-distances.pt",
    map_location=load_to_first_gpu,
)

# %%
import matplotlib.pyplot as plt

dist = distances[0]

for cluster_index in range(10):
    cluster_samples = assignments[0] == cluster_index
    dist_indexes = indexes[0][cluster_samples]
    dist_cluster = dist[cluster_samples]
    indexes_near_cluster_center = dist_indexes[dist_cluster.argsort()][:16]

    _, axs = plt.subplots(4, 4, figsize=(8, 8))
    print(f"==== Cluster {cluster_index} ===")
    for i, row in enumerate(axs):
        for j, col in enumerate(row):
            index = indexes_near_cluster_center[4 * i + j]
            sample, label = mnist[index]
            col.imshow(sample, cmap="Greys", interpolation=None)
            col.set_title(f"Number {label}")
            if i < 3:
                col.set_xticks([])
    plt.show()
# Out:
# ==== Cluster 0 ===
# ==== Cluster 1 ===
# ==== Cluster 2 ===
# ==== Cluster 3 ===
# ==== Cluster 4 ===
# ==== Cluster 5 ===
# ==== Cluster 6 ===
# ==== Cluster 7 ===
# ==== Cluster 8 ===
# ==== Cluster 9 ===

# %%
import torch
import torchvision
import torchvision.transforms as transforms

transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize(mean=0.1306, std=0.3081)]
)

batch_size = 4

trainset = torchvision.datasets.MNIST(
    root="/home/fabian/data/mnist/torchvision-dataset/",
    train=True,
    download=True,
    transform=transform,
)
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=batch_size, shuffle=True, num_workers=2
)

testset = torchvision.datasets.MNIST(
    root="/home/fabian/data/mnist/torchvision-dataset/",
    train=False,
    download=True,
    transform=transform,
)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=batch_size, shuffle=False, num_workers=2
)

classes = (
    "plane",
    "car",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
    "truck",
)

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=5)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=5)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=5)
        self.fc1 = nn.Linear(3 * 3 * 64, 256)
        self.fc2 = nn.Linear(256, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        # x = F.dropout(x, p=0.5, training=self.training)
        x = F.relu(F.max_pool2d(self.conv2(x), 2))
        x = F.dropout(x, p=0.5, training=self.training)
        x = F.relu(F.max_pool2d(self.conv3(x), 2))
        x = F.dropout(x, p=0.5, training=self.training)
        x = x.view(-1, 3 * 3 * 64)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)


cnn = CNN()
print(cnn)

it = iter(train_loader)
X_batch, y_batch = next(it)
print(cnn.forward(X_batch).shape)

# %%
transform = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    ]
)

batch_size = 4

trainset = torchvision.datasets.CIFAR10(
    root="/home/fabian/data/cifar/",
    train=True,
    download=True,
    transform=transform,
)
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=batch_size, shuffle=True, num_workers=2
)

testset = torchvision.datasets.CIFAR10(
    root="/home/fabian/data/cifar/",
    train=False,
    download=True,
    transform=transform,
)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=batch_size, shuffle=False, num_workers=2
)

classes = (
    "plane",
    "car",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
    "truck",
)

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
# %%time
for epoch in range(2):  # loop over the dataset multiple times
    running_loss = 0.0
    for i, data in enumerate(trainloader):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 2000 == 1999:  # print every 2000 mini-batches
            print(f"[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}")
            running_loss = 0.0

print("Finished Training")

# %%
outputs = net(images)

_, predicted = torch.max(outputs, 1)

print("Predicted: ", " ".join(f"{classes[predicted[j]]:5s}" for j in range(4)))

correct = 0
total = 0
# since we're not training, we don't need to calculate the gradients for our outputs
with torch.no_grad():
    for data in testloader:
        images, labels = data
        # calculate outputs by running images through the network
        outputs = net(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(
    f"Accuracy of the network on the 10000 test images: {100 * correct // total} %"
)
